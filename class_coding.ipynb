# %%
class animal:
    """ Animal Class """
    def __init__(
        self,
        name,
        domain,
        kingdom,
        phylum,
        class_,
        order,
        suborder,
        family,
        genus,
        species,
        life_span
    ):
        
        print(" Initializing Animal ")
        self.__name = name
        # repeat for other attributes
    
    @property
    def name(self):
        print(" Getting Name ")
        return self.__name
    
    # Repeat for other attributes
    
    @name.setter
    def name(self, new_name):
        print(" Setting Name ")
        self.__name = new_name
        
    # Repeat for other attributes
    
    @name.deleter
    def name(self):
        print(" Deleting Name ")
        del self.__name
        
    # Repeat for other attributes
    
    def move(self):
        print(' Moving ')
        
    def vocalize(self):
        print(' Vocalizing ')
        
class book:
    """ Book Class """
    def __init__(self, name, author, date, genre):
        print(" Initializing Book ")
        self.__name = name
        self.__author = author
        self.__date = date
        self.__genre = genre
        
    @property
    def name(self):
        print(' Getting Name ')
        return self.__name
        
    @name.setter
    def name(self, new_name):
        print( " Setting Name ")
        self.__name = new_name
    
    @name.deleter
    def name(self):
        print(" Deleting Name ")
        del self.__name
        
class vehicle:
    """ Vehicle Class """
    def __init__(self,*args):
        print(" Initializing Vehicle ")
        #self.__args = arg
        #repeat
        
# I did not go further because it is repetitive and I am moving on
